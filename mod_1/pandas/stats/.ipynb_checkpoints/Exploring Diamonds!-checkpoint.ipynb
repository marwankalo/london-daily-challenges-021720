# %% [markdown]
# ## Exploring Descriptive Statistics

# %% [markdown]
# Use the following dataset to answer the questions about the **diamonds** dataset.

# %%
# Run this cell without changes
import pandas as pd

# %%
# !ls ../pandas-202/
# Out:
# diamonds.csv index.ipynb

# %%
# Run this cell without changes
df = pd.read_csv('../pandas-202/diamonds.csv')
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# **1) What are the mean carat and the median carat for the each group of color in this dataset?**

# %%
mean_carat = df['carat'].mean()
median_carat = df['carat'].median()
print(mean_carat)
print(median_carat)
# Out:
# 0.7979397478680014
# 0.7

# %% [markdown]
# In your own words, how are the mean and median related to each other and what do these values tell us about the distribution of the variable 'Age'

# %%
# The median and the mean are quite similar which indicates there are likely no significant outliers that are skewing
# the data. The data likely follows a symmetrical distribution where the middle value is very near to the average.

# %% [markdown]
# **2) Arrange the table so that the diamonds with the highest carats are listed first.**

# %%
df = df.sort_values(by='carat', ascending=False)
df
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 25999   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# ...      ...        ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31601   0.20    Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
# 31598   0.20  Very Good     E     VS2   63.4   59.0    367   3.74   3.71  2.36
# 14      0.20    Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31599   0.20      Ideal     E     VS2   62.2   57.0    367   3.76   3.73  2.33
# 31593   0.20    Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
#
# ...

# %% [markdown]
# **BONUS 1: Use the seaborn library to make a scatter plot between carat and depth, carat and table, carat and price. Use the hue argument to group by either color or cut**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(10,18))
plt.subplots_adjust(hspace=0.5)

x = df['carat']
y = df['depth']
w = df['table']
z = df['price']


plt.subplot(3, 1, 1)
sns.scatterplot(x,y, hue=df['cut'])
plt.xlabel('Carat', fontsize=20)
plt.ylabel('Depth', fontsize=20)
plt.title('Carat vs Depth', fontsize=20)

plt.subplot(3, 1, 2)
sns.scatterplot(x,w, hue=df['color'])
plt.xlabel('Carat', fontsize=20)
plt.ylabel('Table', fontsize=20)
plt.title('Carat vs Table', fontsize=20)

plt.subplot(3, 1, 3)
sns.scatterplot(x,z, hue=df['color'])
plt.xlabel('Carat', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.title('Carat vs Price', fontsize=20)

plt.show()

# %% [markdown]
# **BONUS 2: Calculate the correlation coeffecient between each continuous variable in this dataset.**

# %%
# Your code here!
correlation_matrix = df.corr()
correlation_matrix['carat']
# Out:
# carat    1.000000
# depth    0.028224
# table    0.181618
# price    0.921591
# x        0.975094
# y        0.951722
# z        0.953387
# Name: carat, dtype: float64

# %% [markdown]
# **BONUS 3: Interpret each correlation coeffecient. Refer to your READMEs, Labs, or external literature if needed!**

# %% [markdown]
# Your answer here!

# %%
# Carat and price have a very strong correlation (close to 1) which indicates they are very strongly positively correlated
# Similarly Carat and variables X, Y and Z have very strong correlations.
# Carat and depth as well as carat and table have a low correlation, near to zero indicating they have almost no relation 

# Diamond depth and table have a weak inverse correlation indicating a negative relationship (-0.3) 

# Diamond depth and table have almost no correlation with price (-0.01 & 0.13)
